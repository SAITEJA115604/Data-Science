# %% [markdown]
# # Linear Regression Model

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("student_scores.csv")

# %%
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model

# %%
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.scatter(df.Hours, df.Scores)

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Hours']], df.Scores)
# Out:
# LinearRegression()

# %%
reg.predict([[4.5]])
# Out:
# array([46.47478866])

# %%
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.scatter(df.Hours, df.Scores)
plt.plot(df.Hours, reg.predict(df[['Hours']]), color='blue')
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.scatter(df.Hours, df.Scores)
plt.plot(df.Hours, reg.predict(df[['Hours']]), color='blue')

# %%
reg.predict(df[['Scores']])
# Out:
# array([207.77554461, 461.94643277, 266.43036496, 735.66892771,
#        295.75777513, 197.99974122, 862.75437179, 589.03187685,
#        794.32374806, 246.87875818, 833.42696162, 608.58348363,
#        403.29161243, 413.06741582, 168.67233105, 931.18499553,
#        295.75777513, 237.10295478, 657.46250059, 677.01410737,
#        295.75777513, 530.37705651, 344.63679208, 745.44473111,
#        843.20276501])

# %%
from scipy import stats

# %%
from sklearn import datasets
df = datasets.load_diabetes()
df
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990842, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06832974, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286377, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04687948,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452837, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00421986,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#         259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#         128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#         150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#         200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#          42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#          83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#         104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#         173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#         107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#          60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#         197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#          59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#         237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#         143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#         142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#          77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#          78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#         154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#          71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#         150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#         145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#          94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#          60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#          31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#         114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#         191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#         244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#         263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#          77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#          58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#         140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#         219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#          43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#         140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#          84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#          94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#         220.,  57.]),
#  'frame': None,
#  'DESCR': '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n  :Number of Instances: 442\n\n  :Number of Attributes: First 10 columns are numeric predictive values\n\n  :Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n  :Attribute Information:\n      - age     age in years\n      - sex\n      - bmi     body mass index\n      - bp      average blood pressure\n      - s1      tc, T-Cells (a type of white blood cells)\n      - s2      ldl, low-density lipoproteins\n      - s3      hdl, high-density lipoproteins\n      - s4      tch, thyroid stimulating hormone\n      - s5      ltg, lamotrigine\n      - s6      glu, blood sugar level\n\nNote: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times `n_samples` (i.e. the sum of squares of each column totals 1).\n\nSource URL:\nhttps://www4.stat.ncsu.edu/~boos/var.select/diabetes.html\n\nFor more information see:\nBradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.\n(https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)',
#  'feature_names': ['age',
#   'sex',
#   'bmi',
#   'bp',
#   's1',
#   's2',
#   's3',
#   's4',
#   's5',
#   's6'],
#  'data_filename': 'C:\\Users\\pc\\anaconda3\\lib\\site-packages\\sklearn\\datasets\\data\\diabetes_data.csv.gz',
#  'target_filename': 'C:\\Users\\pc\\anaconda3\\lib\\site-packages\\sklearn\\datasets\\data\\diabetes_target.csv.gz'}

# %%
df = pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]>

# %%
import seaborn as sns
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_7c2d7_row0_col0,#T_7c2d7_row1_col1,#T_7c2d7_row2_col2,#T_7c2d7_row3_col3,#T_7c2d7_row4_col4,#T_7c2d7_row5_col5,#T_7c2d7_row6_col6,#T_7c2d7_row7_col7,#T_7c2d7_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_7c2d7_row0_col1{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_7c2d7_row0_col2{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_7c2d7_row0_col3,#T_7c2d7_row7_col4{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_7c2d7_row0_col4,#T_7c2d7_row0_col5,#T_7c2d7_row0_col6,#T_7c2d7_row2_col8,#T_7c2d7_row3_col0,#T_7c2d7_row3_col1,#T_7c2d7_row3_col7,#T_7c2d7_row6_col2,#T_7c2d7_row7_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_7c2d7_row0_col7{
#             background-color:  #f1cdba;
#             color:  #000000;
#         }#T_7c2d7_row0_col8,#T_7c2d7_row1_col6{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_7c2d7_row1_col0{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_7c2d7_row1_col2,#T_7c2d7_row6_col8{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_7c2d7_row1_col3{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_7c2d7_row1_col4{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_7c2d7_row1_col5,#T_7c2d7_row3_col6{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_7c2d7_row1_col7{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_7c2d7_row1_col8{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_7c2d7_row2_col0,#T_7c2d7_row7_col2{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_7c2d7_row2_col1{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_7c2d7_row2_col3{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_7c2d7_row2_col4{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_7c2d7_row2_col5,#T_7c2d7_row6_col3{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_7c2d7_row2_col6{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_7c2d7_row2_col7{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_7c2d7_row3_col2,#T_7c2d7_row5_col1{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_7c2d7_row3_col4{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_7c2d7_row3_col5{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_7c2d7_row3_col8{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_7c2d7_row4_col0{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_7c2d7_row4_col1{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_7c2d7_row4_col2{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_7c2d7_row4_col3{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_7c2d7_row4_col5{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_7c2d7_row4_col6{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_7c2d7_row4_col7,#T_7c2d7_row7_col6{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_7c2d7_row4_col8{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_7c2d7_row5_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_7c2d7_row5_col2,#T_7c2d7_row5_col4{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_7c2d7_row5_col3{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_7c2d7_row5_col6,#T_7c2d7_row8_col3{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_7c2d7_row5_col7{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_7c2d7_row5_col8{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_7c2d7_row6_col0{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_7c2d7_row6_col1{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_7c2d7_row6_col4{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_7c2d7_row6_col5{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_7c2d7_row6_col7{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_7c2d7_row7_col0{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_7c2d7_row7_col1{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_7c2d7_row7_col5{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_7c2d7_row7_col8{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_7c2d7_row8_col0,#T_7c2d7_row8_col5{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_7c2d7_row8_col1{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_7c2d7_row8_col2{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_7c2d7_row8_col4{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_7c2d7_row8_col6{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_7c2d7_row8_col7{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }</style><table id="T_7c2d7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pregnancies</th>        <th class="col_heading level0 col1" >Glucose</th>        <th class="col_heading level0 col2" >BloodPressure</th>        <th class="col_heading level0 col3" >SkinThickness</th>        <th class="col_heading level0 col4" >Insulin</th>        <th class="col_heading level0 col5" >BMI</th>        <th class="col_heading level0 col6" >DiabetesPedigreeFunction</th>        <th class="col_heading level0 col7" >Age</th>        <th class="col_heading level0 col8" >Outcome</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7c2d7_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#                         <td id="T_7c2d7_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_7c2d7_row0_col1" class="data row0 col1" >0.129459</td>
#                         <td id="T_7c2d7_row0_col2" class="data row0 col2" >0.141282</td>
#                         <td id="T_7c2d7_row0_col3" class="data row0 col3" >-0.081672</td>
#                         <td id="T_7c2d7_row0_col4" class="data row0 col4" >-0.073535</td>
#                         <td id="T_7c2d7_row0_col5" class="data row0 col5" >0.017683</td>
#                         <td id="T_7c2d7_row0_col6" class="data row0 col6" >-0.033523</td>
#                         <td id="T_7c2d7_row0_col7" class="data row0 col7" >0.544341</td>
#                         <td id="T_7c2d7_row0_col8" class="data row0 col8" >0.221898</td>
#             </tr>
#             <tr>
#                         <th id="T_7c2d7_level0_row1" class="row_heading level0 row1" >Glucose</th>
#                         <td id="T_7c2d7_row1_col0" class="data row1 col0" >0.129459</td>
#                         <td id="T_7c2d7_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_7c2d7_row1_col2" class="data row1 col2" >0.152590</td>
#                         <td id="T_7c2d7_row1_col3" class="data row1 col3" >0.057328</td>
#                         <td id="T_7c2d7_row1_col4" class="data row1 col4" >0.331357</td>

# %%
 errors = model.resid
import statsmodels.api as sm
import scipy.stats as stats
figure = sm.graphics.qqplot(df=errors ,dist=stats.norm,
                         line='45', fit=True)
figure.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5ed9861b1cd2> in <module>
# ----> 1 errors = model.resid
#       2 import statsmodels.api as sm
#       3 import scipy.stats as stats
#       4 figure = sm.graphics.qqplot(df=errors ,dist=stats.norm,
#       5                         line='45', fit=True)
#
# NameError: name 'model' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("diabetes.csv")

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#dataset.drop(columns=['Radio', 'Newspaper'], inplace = True)
#dataset.head()

# %%
x = dataset[['BMI']]
y = dataset[['Outcome']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 100)

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()  
slr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept: ", slr.intercept_)
print("Coefficient: ", slr.coef_)
# Out:
# Intercept:  [-0.22229586]
# Coefficient:  [[0.01806913]]

# %%
y_pred_slr= slr.predict(x_test)
print("Prediction for test set: {}".format(y_pred_slr))
# Out:
# Prediction for test set: [[ 0.56371113]
#  [ 0.42457886]
#  [ 0.4589102 ]
#  [ 0.35591618]
#  [ 0.37579222]
#  [ 0.36314383]
#  [ 0.5167314 ]
#  [ 0.38482678]
#  [ 0.43722725]
#  [ 0.38844061]
#  [ 0.49143463]
#  [ 0.36856457]
#  [ 0.48059315]
#  [ 0.36495074]
#  [ 0.39205443]
#  [ 0.4155443 ]
#  [ 0.22220464]
#  [ 0.40289591]
#  [ 0.54744892]
#  [ 0.32158484]
#  [ 0.41193047]
#  [ 0.14631431]
#  [ 0.35591618]
#  [ 0.56551804]
#  [ 0.54925583]
#  [ 0.56190422]
#  [ 0.51311758]
#  [ 0.31255028]
#  [ 0.77150608]
#  [ 0.36495074]
#  [ 0.31977793]
#  [ 0.45529637]
#  [ 0.37940604]
#  [ 0.24569451]
#  [ 0.3017088 ]
#  [ 0.22762538]
#  [ 0.39024752]
#  [ 0.13908666]
#  [ 0.59984938]
#  [ 0.42819268]
#  [ 0.48420698]
#  [ 0.38482678]
#  [ 0.48962771]
#  [ 0.21678391]
#  [ 0.28002585]
#  [ 0.41915812]
#  [ 0.18606639]
#  [ 0.45710329]
#  [ 0.56551804]
#  [ 0.41193047]
#  [ 0.41915812]
#  [ 0.11017606]
#  [ 0.34868853]
#  [ 0.46071711]
#  [ 0.50408302]
#  [ 0.39747517]
#  [ 0.19148713]
#  [ 0.27641202]
#  [ 0.40831665]
#  [ 0.29628806]
#  [ 0.39386134]
#  [ 0.41915812]
#  [ 0.36314383]
#  [ 0.42457886]
#  [ 0.20413552]
#  [ 0.3161641 ]
#  [ 0.33423323]
#  [ 0.2583429 ]
#  [ 0.33784705]
#  [ 0.21859082]
#  [ 0.1589627 ]
#  [ 0.43903416]
#  [ 0.22581847]
#  [ 0.47878624]
#  [ 0.31435719]
#  [ 0.43361342]
#  [ 0.23304612]
#  [ 0.48962771]
#  [ 0.39205443]
#  [ 0.55286966]
#  [ 0.25111525]
#  [ 0.37940604]
#  [ 0.45348946]
#  [ 0.2727982 ]
#  [ 0.36314383]
#  [ 0.31435719]
#  [ 0.23846686]
#  [ 0.46794476]
#  [ 0.51131067]
#  [ 0.27460511]
#  [ 0.32158484]
#  [ 0.26737746]
#  [ 0.45710329]
#  [ 0.41373738]
#  [-0.22229586]
#  [ 0.32519866]
#  [ 0.4444549 ]
#  [ 0.4733655 ]
#  [ 0.46975168]
#  [ 0.28906041]
#  [ 0.39386134]
#  [ 0.48962771]
#  [ 0.51492449]
#  [ 0.40650973]
#  [ 0.24569451]
#  [ 0.27821894]
#  [ 0.32881249]
#  [ 0.51131067]
#  [ 0.44264799]
#  [ 0.4733655 ]
#  [ 0.32881249]
#  [ 0.31797101]
#  [ 0.41735121]
#  [ 0.25111525]
#  [ 0.44987564]
#  [ 0.18245257]
#  [ 0.45710329]
#  [ 0.34146088]
#  [ 0.32339175]
#  [ 0.42096503]
#  [ 0.28002585]
#  [ 0.26737746]
#  [ 0.38663369]
#  [ 0.27641202]
#  [ 0.2294323 ]
#  [ 0.27099129]
#  [ 0.2872535 ]
#  [ 0.35591618]
#  [ 0.39747517]
#  [ 0.23485303]
#  [ 0.20594243]
#  [ 0.61069086]
#  [ 0.54383509]
#  [ 0.33965397]
#  [ 0.37940604]
#  [ 0.40470282]
#  [ 0.25653598]
#  [ 0.38482678]
#  [-0.22229586]
#  [ 0.5022761 ]
#  [ 0.4589102 ]
#  [ 0.49685536]
#  [ 0.23304612]
#  [ 0.40831665]
#  [ 0.43361342]
#  [ 0.4155443 ]
#  [ 0.40289591]
#  [ 0.29628806]
#  [ 0.26918437]
#  [ 0.14631431]
#  [ 0.42457886]
#  [ 0.34868853]
#  [ 0.39566826]
#  [ 0.39205443]
#  [ 0.27821894]
#  [ 0.29990189]
#  [ 0.36314383]
#  [ 0.46071711]
#  [ 0.52215214]
#  [ 0.46071711]
#  [ 0.20955626]
#  [ 0.22401156]
#  [ 0.37940604]
#  [ 0.52757288]
#  [ 0.35591618]
#  [ 0.1878733 ]
#  [ 0.34146088]
#  [ 0.16076962]
#  [ 0.46794476]
#  [ 0.23304612]
#  [ 0.49324154]
#  [ 0.34868853]
#  [ 0.46433094]
#  [ 0.28544659]
#  [ 0.4299996 ]
#  [ 0.61249777]
#  [ 0.61791851]
#  [ 0.20413552]
#  [ 0.24569451]
#  [ 0.36314383]
#  [ 0.2727982 ]
#  [ 0.50046919]
#  [ 0.59623556]
#  [ 0.43722725]
#  [ 0.34868853]
#  [ 0.51131067]
#  [ 0.28002585]
#  [ 0.38482678]
#  [ 0.27641202]
#  [ 0.39747517]
#  [ 0.37940604]
#  [ 0.19510096]
#  [ 0.40470282]
#  [ 0.31435719]
#  [ 0.32700558]
#  [ 0.21678391]
#  [ 0.31435719]
#  [ 0.38844061]
#  [ 0.32881249]
#  [ 0.6739328 ]
#  [ 0.85101024]
#  [ 0.38482678]
#  [ 0.34146088]
#  [ 0.38301987]
#  [ 0.81306508]
#  [ 0.48962771]
#  [ 0.57635952]
#  [ 0.37759913]
#  [ 0.20955626]
#  [ 0.36314383]
#  [ 0.19510096]
#  [ 0.35591618]
#  [ 0.41735121]
#  [ 0.67573972]
#  [ 0.6016563 ]
#  [ 0.37217839]
#  [ 0.41012356]
#  [ 0.30712954]
#  [ 0.44987564]
#  [ 0.25111525]
#  [ 0.72271944]
#  [ 0.39747517]
#  [ 0.19510096]
#  [ 0.4155443 ]
#  [ 0.2438876 ]
#  [ 0.31435719]
#  [ 0.37940604]
#  [ 0.21497699]
#  [ 0.39205443]
#  [ 0.37037148]
#  [ 0.21497699]]

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, y_pred_slr, 'Red')
plt.show()

# %%
from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred_slr)
meanSqErr = metrics.mean_squared_error(y_test, y_pred_slr)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_slr))
print('R squared: {:.2f}'.format(slr.score(x,y)*100))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)
# Out:
# R squared: 8.54
# Mean Absolute Error: 0.429561440107271
# Mean Square Error: 0.21189881144920775
# Root Mean Square Error: 0.46032468046934844
